# %%
import csv
import matplotlib.pyplot as plt
f = open('age.csv')
data = csv.reader(f)
header = next(data)
for row in data:
    if '신도림' in row[0]:
        for i in row[:]:
            print(i, end=' ')
# Out:
# 서울특별시 구로구 신도림동(1153051000) 37,268 37,268 326 334 406 413 389 408 417 434 411 387 420 383 354 357 340 338 349 339 407 380 390 453 424 516 451 466 448 484 471 476 558 541 579 619 638 740 756 792 745 789 671 687 700 636 726 691 657 619 649 585 579 470 522 534 563 445 511 569 572 513 532 456 426 497 379 384 399 279 289 276 268 271 223 170 150 154 177 140 126 114 121 97 86 80 59 48 44 43 28 29 22 15 13 12 5 8 5 4 2 3 7

# %%
f = open('age.csv')
data = csv.reader(f)
header = next(data)
result =[]
for row in data:
    if '신도림' in row[0]:
        for i in row[3:]:
            result.append(int(i))
print(result)

plt.style.use('ggplot')
plt.plot(result)
plt.bar(range(101), result)
plt.show()
# Out:
# [326, 334, 406, 413, 389, 408, 417, 434, 411, 387, 420, 383, 354, 357, 340, 338, 349, 339, 407, 380, 390, 453, 424, 516, 451, 466, 448, 484, 471, 476, 558, 541, 579, 619, 638, 740, 756, 792, 745, 789, 671, 687, 700, 636, 726, 691, 657, 619, 649, 585, 579, 470, 522, 534, 563, 445, 511, 569, 572, 513, 532, 456, 426, 497, 379, 384, 399, 279, 289, 276, 268, 271, 223, 170, 150, 154, 177, 140, 126, 114, 121, 97, 86, 80, 59, 48, 44, 43, 28, 29, 22, 15, 13, 12, 5, 8, 5, 4, 2, 3, 7]

# %%
import csv 

f = open('age.csv')
data = csv.reader(f)
result = []
name = input("단위을 입력해주세요")

for row in data:
    if name in row[0]:
        for i in row[3:]:
            result.append(int(i.replace(',','')))
            

plt.style.use('ggplot')
plt.rc('font', family='Malgun Gothic')
plt.title(name + '지역의 인구 구조')
plt.plot(result)
plt.show()
# Out:
# 단위을 입력해주세요아름동

# %%
# 막대그래프 그리기
#   bar(막대를 표시할 위치, 막대의 높이)
plt.bar([0, 1, 2, 4, 6, 10], [1, 2, 3, 5, 6, 7])
plt.show()

# %%
f = open('age.csv')
data = csv.reader(f)
header = next(data)
result =[]
for row in data:
    if '신도림' in row[0]:
        for i in row[3:]:
            result.append(int(i))
print(result)

plt.style.use('ggplot')
plt.barh(range(101), result)
# Out:
# [326, 334, 406, 413, 389, 408, 417, 434, 411, 387, 420, 383, 354, 357, 340, 338, 349, 339, 407, 380, 390, 453, 424, 516, 451, 466, 448, 484, 471, 476, 558, 541, 579, 619, 638, 740, 756, 792, 745, 789, 671, 687, 700, 636, 726, 691, 657, 619, 649, 585, 579, 470, 522, 534, 563, 445, 511, 569, 572, 513, 532, 456, 426, 497, 379, 384, 399, 279, 289, 276, 268, 271, 223, 170, 150, 154, 177, 140, 126, 114, 121, 97, 86, 80, 59, 48, 44, 43, 28, 29, 22, 15, 13, 12, 5, 8, 5, 4, 2, 3, 7]
# <BarContainer object of 101 artists>

# %%
# 항아리 데이터 만들기
f = open('gender.csv')
data = csv.reader(f)

m =[]
f =[]
name = input('찾고 싶은 지역의 이름 :')

for row in data:
    if name in row[0]:
        for i in row[3:104]:
            m.append(int(i))
        for i in row[106:]:
            f.append(-int(i))

plt.style.use('ggplot')
plt.figure(figsize = (10,5), dpi=300) # 그래프 사이즈 키워주기
plt.rc('font', family='Malgun Gothic') # 그래프 폰트 정하기
plt.rcParams['axes.unicode_minus'] = False # 그래프 코드 꺠지는거 막아주기
plt.barh(range(101), m, label='남자')
plt.barh(range(101), f, label='여자')
plt.legend()
plt.show()
# Out:
# 찾고 싶은 지역의 이름 :도담동

# %%
import csv
f= open('gender.csv')
data = csv.reader(f)

m =[]
f =[]


name = input('찾고 싶은 지역')
for row in data:
    if name in row[0]:
        for i in row[3:104]:
            m.append(-int(i.replace(',','')))
        for i in row[106:]:
            f.append(int(i.replace(',','')))
plt.style.use('ggplot')
plt.figure(figsize = (10,5), dpi=300) # 그래프 사이즈 키워주기
plt.rc('font', family='Malgun Gothic') # 그래프 폰트 정하기
plt.rcParams['axes.unicode_minus'] = False # 그래프 코드 꺠지는거 막아주기
plt.barh(range(101), m, label='남자')
plt.barh(range(101), f, label='여자')
plt.legend()
plt.show()
# Out:
# 찾고 싶은 지역제주특별자치도
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-5203588ce847> in <module>
#      18 plt.rc('font', family='Malgun Gothic') # 그래프 폰트 정하기
#      19 plt.rcParams['axes.unicode_minus'] = False # 그래프 코드 꺠지는거 막아주기
# ---> 20 plt.barh(range(101), m, label='남자')
#      21 plt.barh(range(101), f, label='여자')
#      22 plt.legend()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in barh(y, width, height, left, align, **kwargs)
#    2452 def barh(y, width, height=0.8, left=None, *, align='center', **kwargs):
#    2453     return gca().barh(
# -> 2454         y, width, height=height, left=left, align=align, **kwargs)
#    2455
#    2456
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in barh(self, y, width, height, left, align, **kwargs)
#    2595         kwargs.setdefault('orientation', 'horizontal')
# ...

# %%
print(len(m), len(f))
# Out:
# 4646 4646

# %%
import csv
f= open('gender.csv')
data = csv.reader(f)

m =[]
f =[]


name = input('찾고 싶은 지역')
for row in data:
    if name in row[0]:
        for i in row[3:104]:
            m.append(-int(i.replace(',','')))
        for i in row[106:]:
            f.append(int(i.replace(',','')))
        break                               # 원하는지역만 검색하고 조건을 만족하면 멈춘다.
plt.style.use('ggplot')
plt.figure(figsize = (10,5), dpi=300) # 그래프 사이즈 키워주기
plt.rc('font', family='Malgun Gothic') # 그래프 폰트 정하기
plt.rcParams['axes.unicode_minus'] = False # 그래프 코드 꺠지는거 막아주기
plt.barh(range(101), m, label='남자')
plt.barh(range(101), f, label='여자')
plt.legend()
plt.show()
# Out:
# 찾고 싶은 지역제주특별자치도
